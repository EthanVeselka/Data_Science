# %%
from collections import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from sklearn import linear_model

# DATA CLEANING --same for all parts

file_path = "Top_1000_IMDb_movies_New_version.csv"
data = pd.read_csv(file_path, header=0)
clean_data = data.copy()
clean_data = clean_data.replace("#222", "72.5")

# convert format "II 2019" to "2019"
def convert_string(x):
    if x[0] == 'I':
        return x[-4:]
    else:
        return x
clean_data["Year of Release"] = clean_data["Year of Release"].apply(convert_string)

# convert votes to numbers
def convert_to_int(x):
    return int(x.replace(',', ''))
clean_data["Votes"] = clean_data["Votes"].apply(convert_to_int)

# calculate means
Wt_mean = clean_data["Watch Time"].mean()
Rating_mean = clean_data["Movie Rating"].mean()
score_mean = clean_data["Metascore of movie"].mean()
revenue_mean = clean_data["Gross"].apply(float).mean()
votes_mean = clean_data["Votes"].mean()

# Data filling with mean values
clean_data["Watch Time"] = clean_data["Watch Time"].fillna(Wt_mean)
clean_data["Movie Rating"] = clean_data["Movie Rating"].fillna(Rating_mean)
clean_data["Metascore of movie"] = clean_data["Metascore of movie"].fillna(score_mean)
clean_data["Gross"] = clean_data["Gross"].fillna(revenue_mean)
clean_data["Votes"] = clean_data["Votes"].fillna(votes_mean)


print("Shape before clean: ", data.shape)
print("Shape after clean: ", clean_data.shape)

# words and counts in each description
count = Counter()
desc_words = clean_data["Description"].str.split()
for i in desc_words:
    count.update(i)
desc_wc = clean_data["Description"].str.split().apply(len)
# Out:
# Shape before clean:  (1000, 9)
# Shape after clean:  (1000, 9)

# %%
# I: Univariate Stats

YoR_summ = clean_data["Year of Release"].describe()
print("Year of Release Statistics: \n", YoR_summ, "\n")

Wt_summ = clean_data["Watch Time"].describe()
print("Watch Time Statistics: \n", Wt_summ, "\n")

Rating_summ = clean_data["Movie Rating"].describe()
print("Rating Statistics: \n", Rating_summ, "\n")

score_summ = clean_data["Metascore of movie"].describe()
print("Metascore Statistics: \n",score_summ, "\n")

revenue_summ = clean_data["Gross"].apply(float).describe()
print("Gross Revenue Statistics: \n", revenue_summ, "\n")

votes_summ = clean_data["Votes"].describe()
print("Voting Statistics: \n", votes_summ, "\n")

# words and counts in each description
avg_wc = desc_wc.mean()
std_wc = desc_wc.std()
quant_wc = desc_wc.quantile([.25, .5, .75])
print("Description Statistics:")
print("Average word count: ", round(avg_wc))
print("Std: ", round(std_wc))
print("Quantiles:\n", quant_wc)
print("\n")
print("Count dictionary: ", count)
print("50 Most popular words: ", count.most_common(50))
print("50 Least popular words: ", count.most_common()[-50:])

meta = clean_data["Metascore of movie"].apply(float).to_numpy()
rev = clean_data["Gross"].apply(float).to_numpy()
rating = clean_data["Movie Rating"].apply(float).to_numpy()
votes = clean_data["Votes"].apply(float).to_numpy()
print("\n")
print("Correlation of Metascores to Revenue: ")
print(np.corrcoef(meta, rev)[0])
print("Correlation of Ratings to Revenue: ")
print(np.corrcoef(rating, rev)[0])
print("\n")
print("Correlation of Metascores to Votes: ")
print(np.corrcoef(meta, votes)[0])
print("Correlation of Ratings to Votes: ")
print(np.corrcoef(rating, votes)[0])
# Out:
# Year of Release Statistics:
#  count     1000
# unique     102
# top       2014
# freq        31
# Name: Year of Release, dtype: object
#
# Watch Time Statistics:
#  count    1000.000000
# mean      124.253000
# std        28.800355
# min        45.000000
# 25%       103.000000
# 50%       120.000000
# 75%       139.000000
# max       321.000000
# Name: Watch Time, dtype: float64
#
# Rating Statistics:
#  count    1000.000000
# mean        7.970200
# std         0.275732
# min         7.600000
# 25%         7.800000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: Movie Rating, dtype: float64
#
# Metascore Statistics:
#  count    1000.000000
# mean       79.011834
# std        11.005772
# min        28.000000
# 25%        73.000000
# 50%        79.011834
# 75%        86.000000
# max       100.000000
# Name: Metascore of movie, dtype: float64
#
# Gross Revenue Statistics:
#  count    1000.000000
# mean       72.837613
# std       105.220384
# min         0.000000
# 25%         5.010000
# 50%        44.805000
# 75%        72.837613
# max       936.660000
# Name: Gross, dtype: float64
#
# Voting Statistics:
#  count    1.000000e+03
# mean     3.190469e+05
# std      3.871814e+05
# min      2.581300e+04
# 25%      6.238100e+04
# 50%      1.581340e+05
# 75%      4.436372e+05
# max      2.777378e+06
# Name: Votes, dtype: float64
#
# Description Statistics:
# Average word count:  26
# Std:  8
# Quantiles:
#  0.25    21.0
# 0.50    25.0
# 0.75    31.0
# Name: Description, dtype: float64
#
#
# Count dictionary:  Counter({'a': 1244, 'the': 1173, 'to': 855, 'of': 794, 'and': 714, 'his': 568, 'in': 498, 'A': 356, 'is': 264, 'with': 235, 'an': 220, 'on': 193, 'for': 193, 'by': 182, 'her': 173, 'he': 170, 'from': 167, 'who': 162, 'their': 158, 'as': 136, 'young': 127, 'The': 108, 'that': 106, 'man': 84, 'In': 83, 'after': 80, 'life': 79, 'are': 79, 'into': 74, 'at': 72, 'two': 71, 'they': 70, 'but': 69, 'An': 66, 'up': 62, 'when': 60, 'story': 56, 'has': 56, 'When': 55, 'him': 55, 'After': 55, 'must': 54, 'be': 54, 'find': 54, 'family': 50, 'out': 49, 'while': 48, 'finds': 48, 'she': 47, 'woman': 46, 'becomes': 45, 'where': 45, 'love': 45, 'against': 44, 'new': 43, 'War': 42, 'boy': 41, 'help': 40, 'one': 39, 'during': 39, 'girl': 36, 'between': 35, 'Two': 34, 'father': 34, 'World': 33, 'them': 33, 'tries': 32, 'about': 31, 'son': 30, 'American': 30, 'have': 30, 'mysterious': 30, 'world': 30, 'former': 30, 'New': 29, 'old': 29, '-': 29, 'lives': 28, 'team': 28, 'friends': 28, 'years': 28, 'which': 27, 'police': 27, 'only': 27, 'own': 27, 'group': 26, 'being': 25, 'through': 24, 'it': 24, 'each': 24, 'was': 24, 'takes': 24, 'other': 24, 'three': 24, 'search': 24, 'wife': 23, 'himself': 23, 'will': 22, 'goes': 22, 'down': 22, 'mother': 22, 'murder': 21, 'become': 21, 'order': 21, 'can': 21, 'German': 21, 'people': 20, 'journey': 20, 'men': 20, 'leads': 20, 'sets': 20, 'school': 20, 'not': 20, 'get': 20, 'before': 19, 'sent': 19, 'home': 19, 'all': 19, 'war': 19, 'first': 19, 'York': 18, 'what': 18, 'Indian': 18, 'U.S.': 18, 'falls': 18, 'over': 17, 'more': 17, 'past': 17, 'him.': 17, 'back': 17, 'life,': 17, 'small': 17, 'time': 17, 'its': 16, 'how': 16, 'relationship': 16, 'battle': 16, 'struggles': 16, 'learns': 16, 'meet': 16, 'both': 16, 'agent': 16, 'violent': 16, 'forced': 16, 'set': 15, 'save': 15, 'day': 15, 'begins': 15, 'go': 15, 'off': 15, 'gets': 15, 'stop': 15, 'live': 15, 'friend': 15, 'returns': 15, 'discover': 15, 'way': 15, 'series': 15, "father's": 15, 'fight': 14, 'it.': 14, 'discovers': 14, 'During': 14, 'around': 14, 'run': 14, 'under': 14, 'French': 14, 'daughter': 14, 'true': 14, 'take': 14, 'family.': 14, 'Jewish': 13, 'whose': 13, 'powerful': 13, 'lawyer': 13, 'soldiers': 13, 'been': 13, 'them.': 13, 'comes': 13, 'high': 13, 'track': 13, 'teenage': 13, 'mission': 13, 'Los': 13, 'trip': 13, 'town': 13, 'together': 13, 'decides': 12, 'forces': 12, 'early': 12, 'crime': 12, 'case': 12, 'make': 12, 'death': 12, 'village': 12, 'wealthy': 12, 'husband': 12, 'hired': 12, 'officer': 12, 'days': 12, 'film': 12, 'star': 12, 'British': 12, 'this': 12, 'best': 12, 'life.': 12, 'teacher': 12, 'than': 12, 'As': 12, 'Three': 12, 'brother': 12, 'force': 12, 'local': 12, 'themselves': 12, 'several': 11, 'City': 11, 'four': 11, 'may': 11, 'destroy': 11, 'While': 11, 'named': 11, 'John': 11, 'gang': 11, 'events': 11, 'little': 11, 'or': 11, 'ruthless': 11, 'friendship': 11, 'children': 11, 'His': 11, 'quest': 11, 'detective': 11, 'personal': 11, 'child': 11, 'living': 11, 'human': 11, 'older': 11, 'troubled': 11, 'II,': 10, 'career': 10, 'Earth': 10, 'most': 10, 'killer': 10, 'now': 10, 'protect': 10, 'power': 10, 'meets': 10, 'crew': 10, 'tells': 10, 'sister': 10, 'struggle': 10, 'escape': 10, 'government': 10, 'secret': 10, 'plan': 10, 'couple': 10, 'real': 10, 'last': 10, 'leaves': 10, 'return': 10, 'just': 10, 'trying': 10, 'look': 10, 'work': 10, 'future': 10, 'band': 10, 'accused': 10, 'seeks': 10, 'car': 10, 'lead': 9, 'gangster': 9, 'race': 9, 'makes': 9, 'Korean': 9, 'veteran': 9, 'Based': 9, 'even': 9, 'murdered': 9, 'attempt': 9, 'taken': 9, 'professional': 9, 'lover': 9, 'assassin': 9, 'With': 9, 'attempts': 9, 'herself': 9, 'end': 9, 'drug': 9, 'King': 9, 'begin': 9, 'fellow': 9, 'fighting': 9, 'city': 9, 'Russian': 9, 'turn': 9, 'befriends': 9, 'student': 9, 'unlikely': 9, 'agrees': 9, 'mother,': 9, 'no': 9, 'form': 8, 'family,': 8, 'known': 8, 'army': 8, 'across': 8, 'mob': 8, 'childhood': 8, 'joins':  ...
# 50 Most popular words:  [('a', 1244), ('the', 1173), ('to', 855), ('of', 794), ('and', 714), ('his', 568), ('in', 498), ('A', 356), ('is', 264), ('with', 235), ('an', 220), ('on', 193), ('for', 193), ('by', 182), ('her', 173), ('he', 170), ('from', 167), ('who', 162), ('their', 158), ('as', 136), ('young', 127), ('The', 108), ('that', 106), ('man', 84), ('In', 83), ('after', 80), ('life', 79), ('are', 79), ('into', 74), ('at', 72), ('two', 71), ('they', 70), ('but', 69), ('An', 66), ('up', 62), ('when', 60), ('story', 56), ('has', 56), ('When', 55), ('him', 55), ('After', 55), ('must', 54), ('be', 54), ('find', 54), ('family', 50), ('out', 49), ('while', 48), ('finds', 48), ('she', 47), ('woman', 46)]
# 50 Least popular words:  [('diagnosis', 1), ('subsequent', 1), ('beat', 1), ('renowned', 1), ('playwright', 1), ('enticed', 1), ('hellish', 1), ('freak', 1), ('critically', 1), ('born-again', 1), ('ex-con.', 1), ('hijack', 1), ('subway', 1), ('demand', 1), ('ransom', 1), ('passengers.', 1), ('conundrum:', 1), ('Even', 1), ('paid,', 1), ('away?', 1), ('profile', 1), ('Ian', 1), ('Curtis,', 1), ('enigmatic', 1), ('Joy', 1), ('Division', 1), ('personal,', 1), ('professional,', 1), ('23.', 1), ('world-weary', 1), ('convent.', 1), ('fiancé,', 1), ('trenches', 1), ('Somme', 1), ('One.', 1), ('Pianist', 1), ('Helfgott,', 1), ('teachers,', 1), ('breakdown.', 1), ('piano,', 1), ('critical', 1), ('acclaim.', 1), ('invisible,', 1), ('so,', 1), ('murderously', 1), ('riot', 1), ('inmate', 1), ('guard', 1), ('revolt,', 1), ('ordeal.', 1)]
#
#
# Correlation of Metascores to Revenue:
# [ 1.         -0.05995249]
# Correlation of Ratings to Revenue:
# [1.         0.12648467]
#
#
# Correlation of Metascores to Votes:
# [ 1.         -0.06333825]
# Correlation of Ratings to Votes:
# [1.         0.48381338]
